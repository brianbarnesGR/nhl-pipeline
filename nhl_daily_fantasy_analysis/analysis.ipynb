# %%
# import pandas as pd
from sites import draftkings

# %%
draftkings.get_contests('nhl')
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File ~/Source/nhl-daily-fantasy-analysis/.venv/lib/python3.13/site-packages/urllib3/response.py:748, in HTTPResponse._error_catcher(self)
#     747 try:
# --> 748     yield
#     750 except SocketTimeout as e:
#     751     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     752     # there is yet no clean way to get at it from this context.
#
# File ~/Source/nhl-daily-fantasy-analysis/.venv/lib/python3.13/site-packages/urllib3/response.py:1209, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1208     break
# -> 1209 chunk = self._handle_chunk(amt)
#    1210 decoded = self._decode(
#    1211     chunk, decode_content=decode_content, flush_decoder=False
#    1212 )
#
# ...
